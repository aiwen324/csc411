# %% [markdown]
# ## Gradient Descent for Functions of One Variable
#
# Consider the function
#
# $$f(x) = .1 x^2 + \sin(.1 (x-2)^2)$$

# %% [markdown]
# The derivative for that function is
#
# $$f'(x) = .2 x+ \cos(.1 (x-2)^2)(.2(x-2))$$

# %% [markdown]
# Let's graph the function first:

# %%
#Needed to display images inline in Jupyter
# %matplotlib inline  
####################################

from numpy import *
from matplotlib.pyplot import *

def f(x):
    return .1*x**2 + sin(.1*(x-2)**2)

def dfdx(x):
    return .2*x+cos(.1*(x-2)**2)*(.2*(x-2))

# %%
# How to check gradient?

# %%
x = 2
h = 0.00001

print (f(x + h) - f(x)) / h
print dfdx(x)
# Out:
# 0.400002000001
# 0.4

# %%
x = arange(-10, 10, .1)
y = f(x)

figure(1)
plot(x, y)
xlabel("x")
ylabel("$.1 x^2 + sin(.1 (x-2)^2)$")
show()

# %% [markdown]
# We can now write the gradient descent algorithm

# %%
def grad_descent(f, dfdx, init_x, alpha):
    EPS = 1e-3
    prev_x = init_x-2*EPS
    x = init_x
    
    iter = 0
    while abs(x - prev_x) >  EPS:
        prev_x = x
        x -= alpha*dfdx(x)
        
        print "Iter %d: x = %.2f, f(x) = %.2f"  % (iter, x, f(x))
        iter += 1
        if iter > 1000:
            break
    
    return x

# %% [markdown]
# Let's try running gradient descent starting from the initial guess of 8.

# %%
grad_descent(f, dfdx, 8, 10.0)
# Out:
# Iter 0: x = 2.76, f(x) = 0.82
# Iter 1: x = -4.28, f(x) = 1.11
# Iter 2: x = -4.44, f(x) = 1.13
# Iter 3: x = -2.43, f(x) = 1.51
# Iter 4: x = -0.93, f(x) = 0.84
# Iter 5: x = 4.76, f(x) = 2.96
# Iter 6: x = -8.75, f(x) = 6.82
# Iter 7: x = 20.37, f(x) = 42.22
# Iter 8: x = 5.23, f(x) = 3.60
# Iter 9: x = -8.48, f(x) = 6.18
# Iter 10: x = 8.00, f(x) = 5.96
# Iter 11: x = 2.74, f(x) = 0.80
# Iter 12: x = -4.21, f(x) = 1.12
# Iter 13: x = -5.21, f(x) = 1.83
# Iter 14: x = 11.96, f(x) = 13.83
# Iter 15: x = 5.51, f(x) = 3.97
# Iter 16: x = -7.85, f(x) = 5.89
# Iter 17: x = -11.05, f(x) = 11.24
# Iter 18: x = 4.56, f(x) = 2.69
# Iter 19: x = -8.62, f(x) = 6.47
# Iter 20: x = 14.62, f(x) = 21.16
# Iter 21: x = 10.04, f(x) = 10.25
# Iter 22: x = -25.86, f(x) = 67.67
# Iter 23: x = -7.91, f(x) = 5.87
# Iter 24: x = -10.31, f(x) = 11.16
# Iter 25: x = -10.51, f(x) = 11.11
# Iter 26: x = -14.45, f(x) = 21.81
# Iter 27: x = 3.18, f(x) = 1.15
# Iter 28: x = -5.51, f(x) = 2.44
# Iter 29: x = 17.59, f(x) = 30.18
# Iter 30: x = -38.42, f(x) = 147.65
# Iter 31: x = 119.24, f(x) = 1420.73
# Iter 32: x = -115.95, f(x) = 1344.92
# Iter 33: x = -87.73, f(x) = 770.39
# Iter 34: x = 203.13, f(x) = 4125.47
# Iter 35: x = -439.70, f(x) = 19333.44
# Iter 36: x = 1302.54, f(x) = 169660.69
# Iter 37: x = 232.26, f(x) = 5393.81
# Iter 38: x = -513.39, f(x) = 26356.43
# Iter 39: x = -396.80, f(x) = 15746.04
# Iter 40: x = 510.89, f(x) = 26100.24
# Iter 41: x = 84.08, f(x) = 707.99
# Iter 42: x = -101.50, f(x) = 1030.28
# Iter 43: x = -104.38, f(x) = 1089.97
# Iter 44: x = 280.98, f(x) = 7893.90
# Iter 45: x = -0.89, f(x) = 0.82
# Iter 46: x = 4.77, f(x) = 2.97
# Iter 47: x = -8.76, f(x) = 6.83
# Iter 48: x = 20.49, f(x) = 42.34
# Iter 49: x = 13.80, f(x) = 20.02
# Iter 50: x = -18.80, f(x) = 34.70
# Iter 51: x = 50.43, f(x) = 255.18
# Iter 52: x = -6.30, f(x) = 4.53
# Iter 53: x = 19.98, f(x) = 40.70
# Iter 54: x = -42.20, f(x) = 178.56
# Iter 55: x = 117.90, f(x) = 1388.99
# Iter 56: x = -161.01, f(x) = 2592.11
# Iter 57: x = 455.31, f(x) = 20730.88
# Iter 58: x = 440.92, f(x) = 19441.25
# Iter 59: x = -1198.09, f(x) = 143540.48
# Iter 60: x = -449.00, f(x) = 20160.64
# Iter 61: x = 870.65, f(x) = 75804.13
# Iter 62: x = -2094.32, f(x) = 438617.08
# Iter 63: x = 130.12, f(x) = 1694.23
# Iter 64: x = -104.00, f(x) = 1080.81
# Iter 65: x = 214.07, f(x) = 4581.70
# Iter 66: x = -320.13, f(x) = 10248.23
# Iter 67: x = -308.82, f(x) = 9536.48
# Iter 68: x = -283.12, f(x) = 8014.73
# Iter 69: x = 513.77, f(x) = 26396.53
# Iter 70: x = 322.63, f(x) = 10409.49
# Iter 71: x = -760.40, f(x) = 57820.92
# Iter 72: x = 2271.77, f(x) = 516094.95
# Iter 73: x = 2096.11, f(x) = 439369.82
# Iter 74: x = 1980.07, f(x) = 392067.41
# Iter 75: x = 144.74, f(x) = 2095.86
# Iter 76: x = -131.89, f(x) = 1740.45
# Iter 77: x = 23.00, f(x) = 53.02
# Iter 78: x = -64.71, f(x) = 417.76
# Iter 79: x = 119.37, f(x) = 1425.95
# Iter 80: x = -116.44, f(x) = 1356.79
# Iter 81: x = 105.84, f(x) = 1119.58
# Iter 82: x = 40.71, f(x) = 164.87
# Iter 83: x = -84.07, f(x) = 706.18
# Iter 84: x = 223.75, f(x) = 5005.73
# Iter 85: x = 140.60, f(x) = 1975.75
# Iter 86: x = -88.67, f(x) = 785.30
# Iter 87: x = 177.37, f(x) = 3146.16
# Iter 88: x = 160.20, f(x) = 2567.29
# Iter 89: x = -31.62, f(x) = 99.94
# Iter 90: x = 98.76, f(x) = 975.56
# Iter 91: x = -290.67, f(x) = 8449.91
# Iter 92: x = 275.71, f(x) = 7602.46
# Iter 93: x = 54.06, f(x) = 292.94
# Iter 94: x = -125.49, f(x) = 1573.82
# Iter 95: x = 11.00, f(x) = 13.06
# Iter 96: x = -6.74, f(x) = 5.51
# Iter 97: x = 10.58, f(x) = 12.07
# Iter 98: x = -18.74, f(x) = 34.27
# Iter 99: x = 41.77, f(x) = 175.37
# Iter 100: x = -78.45, f(x) = 615.36
# Iter 101: x = 239.31, f(x) = 5727.99
# Iter 102: x = -25.14, f(x) = 62.21
# Iter 103: x = 15.86, f(x) = 25.49
# Iter 104: x = -41.85, f(x) = 174.54
# Iter 105: x = -27.87, f(x) = 78.63
# Iter 106: x = 46.06, f(x) = 211.49
# Iter 107: x = -114.40, f(x) = 1307.94
# Iter 108: x = -53.41, f(x) = 284.58
# Iter 109: x = 129.88, f(x) = 1687.95
# Iter 110: x = -72.36, f(x) = 523.75
# Iter 111: x = 220.50, f(x) = 4860.89
# Iter 112: x = -379.87, f(x) = 14429.56
# Iter 113: x = 957.30, f(x) = 91642.58
# Iter 114: x = 479.91, f(x) = 23031.09
# Iter 115: x = -1433.00, f(x) = 205348.37
# Iter 116: x = -1425.43, f(x) = 203184.36
# Iter 117: x = 1672.28, f(x) = 279651.34
# Iter 118: x = 1190.47, f(x) = 141720.21
# Iter 119: x = -2783.50, f(x) = 774786.96
# Iter 120: x = 1552.32, f(x) = 240970.22
# Iter 121: x = -4263.13, f(x) = 1817426.37
# Iter 122: x = 11862.29, f(x) = 14071392.44
# Iter 123: x = -4744.57, f(x) = 2251091.79
# Iter 124: x = -3907.35, f(x) = 1526742.33
# Iter 125: x = 4213.35, f(x) = 1775234.65
# Iter 126: x = -10858.97, f(x) = 11791717.64
# Iter 127: x = -3145.05, f(x) = 989132.68
# Iter 128: x = 4813.82, f(x) = 2317285.40
# Iter 129: x = -14388.97, f(x) = 20704241.52
# Iter 130: x = -1091.92, f(x) = 119229.24
# Iter 131: x = -1068.17, f(x) = 114099.09
# Iter 132: x = -1044.31, f(x) = 109057.46
# Iter 133: x = 897.70, f(x) = 80585.64
# Iter 134: x = 252.40, f(x) = 6369.93
# Iter 135: x = -652.21, f(x) = 42537.15
# Iter 136: x = 583.12, f(x) = 34001.86
# Iter 137: x = 379.87, f(x) = 14430.09
# Iter 138: x = 355.51, f(x) = 12638.17
# Iter 139: x = -991.02, f(x) = 98212.02
# Iter 140: x = 2910.20, f(x) = 846925.56
# Iter 141: x = -7729.55, f(x) = 5974595.15
# Iter 142: x = -4503.61, f(x) = 2028248.20
# Iter 143: x = -3969.97, f(x) = 1576067.32
# Iter 144: x = 8207.31, f(x) = 6735995.27
# Iter 145: x = 3167.48, f(x) = 1003293.34
# Iter 146: x = 1549.72, f(x) = 240162.78
# Iter 147: x = 1492.87, f(x) = 222867.05
# Iter 148: x = -1326.40, f(x) = 175935.37
# Iter 149: x = -631.49, f(x) = 39877.09
# Iter 150: x = 1836.07, f(x) = 337115.70
# Iter 151: x = -4795.39, f(x) = 2299580.37
# Iter 152: x = 14165.61, f(x) = 20066459.67
# Iter 153: x = 13783.46, f(x) = 18998380.05
# Iter 154: x = -25616.02, f(x) = 65618060.17
# Iter 155: x = 4490.80, f(x) = 2016728.63
# Iter 156: x = 4051.50, f(x) = 1641465.72
# Iter 157: x = 790.55, f(x) = 62497.36
# Iter 158: x = 732.08, f(x) = 53595.64
# Iter 159: x = -28.28, f(x) = 79.43
# Iter 160: x = -22.53, f(x) = 50.30
# Iter 161: x = -21.27, f(x) = 44.57
# Iter 162: x = -12.74, f(x) = 16.49
# Iter 163: x = -15.60, f(x) = 23.89
# Iter 164: x = 47.30, f(x) = 222.89
# Iter 165: x = 0.35, f(x) = 0.28
# Iter 166: x = 2.84, f(x) = 0.88
# Iter 167: x = -4.52, f(x) = 1.15
# Iter 168: x = -1.31, f(x) = 1.06
# Iter 169: x = 4.34, f(x) = 2.41
# Iter 170: x = -8.34, f(x) = 6.00
# Iter 171: x = 2.13, f(x) = 0.46
# Iter 172: x = -2.40, f(x) = 1.51
# Iter 173: x = -0.73, f(x) = 0.73
# Iter 174: x = 4.74, f(x) = 2.93
# Iter 175: x = -8.75, f(x) = 6.80
# Iter 176: x = 20.09, f(x) = 41.32
# Iter 177: x = -29.64, f(x) = 87.44
# Iter 178: x = 87.35, f(x) = 762.79
# Iter 179: x = -250.28, f(x) = 6264.14
# Iter 180: x = 752.07, f(x) = 56562.35
# Iter 181: x = -1135.26, f(x) = 128881.54
# Iter 182: x = 16.65, f(x) = 28.23
# Iter 183: x = 8.67, f(x) = 6.55
# Iter 184: x = -5.21, f(x) = 1.82
# Iter 185: x = 11.85, f(x) = 13.77
# Iter 186: x = 7.09, f(x) = 5.55
# Iter 187: x = 1.56, f(x) = 0.26
# Iter 188: x = -0.67, f(x) = 0.70
# Iter 189: x = 4.71, f(x) = 2.89
# Iter 190: x = -8.73, f(x) = 6.76
# Iter 191: x = 19.49, f(x) = 37.28
# Iter 192: x = -43.61, f(x) = 190.86
# Iter 193: x = 112.91, f(x) = 1273.85
# Iter 194: x = -143.96, f(x) = 2072.61
# Iter 195: x = 423.03, f(x) = 17896.62
# Iter 196: x = -24.48, f(x) = 60.74
# Iter 197: x = 53.75, f(x) = 288.21
# Iter 198: x = 21.04, f(x) = 43.26
# Iter 199: x = -25.22, f(x) = 62.64
# Iter 200: x = 39.35, f(x) = 155.78
# Iter 201: x = -62.27, f(x) = 386.77
# Iter 202: x = 57.25, f(x) = 327.25
# Iter 203: x = 40.83, f(x) = 166.76
# Iter 204: x = -118.49, f(x) = 1404.51
# Iter 205: x = 335.35, f(x) = 11245.56
# Iter 206: x = 303.63, f(x) = 9219.16
# Iter 207: x = -906.64, f(x) = 82200.42
# Iter 208: x = 1163.10, f(x) = 135279.94
# Iter 209: x = 544.89, f(x) = 29690.08
# Iter 210: x = -1097.22, f(x) = 120389.29
# Iter 211: x = 132.26, f(x) = 1749.32
# Iter 212: x = -388.57, f(x) = 15097.37
# Iter 213: x = 528.01, f(x) = 27878.93
# Iter 214: x = 122.61, f(x) = 1503.20
# Iter 215: x = 118.44, f(x) = 1401.81
# Iter 216: x = -167.54, f(x) = 2807.14
# Iter 217: x = -171.48, f(x) = 2940.32
# Iter 218: x = 513.55, f(x) = 26372.47
# Iter 219: x = -961.92, f(x) = 92527.49
# Iter 220: x = -502.71, f(x) = 25272.56
# Iter 221: x = 948.38, f(x) = 89942.62
# Iter 222: x = 905.96, f(x) = 82077.33
# Iter 223: x = -992.65, f(x) = 98534.44
# Iter 224: x = -964.11, f(x) = 92950.72
# Iter 225: x = 2895.89, f(x) = 838617.39
# Iter 226: x = -7602.86, f(x) = 5780350.24
# Iter 227: x = 9236.42, f(x) = 8531149.44
# Iter 228: x = -15751.27, f(x) = 24810241.92
# Iter 229: x = 3298.32, f(x) = 1087893.98
# Iter 230: x = -8395.31, f(x) = 7048124.54
# Iter 231: x = 10648.19, f(x) = 11338398.89
# Iter 232: x = -10711.69, f(x) = 11474021.97
# Iter 233: x = 21375.16, f(x) = 45689740.35
# Iter 234: x = -42930.76, f(x) = 184305023.30
# Iter 235: x = 55045.34, f(x) = 302998950.99
# Iter 236: x = -39882.30, f(x) = 159059759.69
# Iter 237: x = 118648.39, f(x) = 1407744073.12
# Iter 238: x = 28816.92, f(x) = 83041485.31
# Iter 239: x = -34999.65, f(x) = 122497573.18
# Iter 240: x = -33100.25, f(x) = 109562637.01
# Iter 241: x = 12715.98, f(x) = 16169602.29
# Iter 242: x = -23165.34, f(x) = 53663288.48
# Iter 243: x = 13523.56, f(x) = 18288663.30
# Iter 244: x = -28081.92, f(x) = 78859427.59
# Iter 245: x = -3004.36, f(x) = 902618.42
# Iter 246: x = -1448.98, f(x) = 209953.85
# Iter 247: x = -1224.19, f(x) = 149863.41
# Iter 248: x = -1227.46, f(x) = 150666.36
# Iter 249: x = -973.14, f(x) = 94701.93
# Iter 250: x = 2005.13, f(x) = 402055.62
# Iter 251: x = -902.60, f(x) = 81467.63
# Iter 252: x = -845.01, f(x) = 71405.67
# Iter 253: x = 673.81, f(x) = 45403.63
# Iter 254: x = -901.16, f(x) = 81210.38
# Iter 255: x = 65.46, f(x) = 429.16
# Iter 256: x = -166.60, f(x) = 2776.08
# Iter 257: x = -130.60, f(x) = 1704.94
# Iter 258: x = 292.47, f(x) = 8552.94
# Iter 259: x = -565.45, f(x) = 31972.45
# Iter 260: x = 844.49, f(x) = 71315.43
# Iter 261: x = 545.03, f(x) = 29706.78
# Iter 262: x = -899.75, f(x) = 80953.64
# Iter 263: x = -317.48, f(x) = 10079.64
# Iter 264: x = -297.06, f(x) = 8824.88
# Iter 265: x = -256.76, f(x) = 6591.79
# Iter 266: x = -16.81, f(x) = 27.53
# Iter 267: x = -8.42, f(x) = 6.10
# Iter 268: x = 5.54, f(x) = 4.02
# Iter 269: x = -7.74, f(x) = 5.93
# Iter 270: x = -11.71, f(x) = 13.64
# Iter 271: x = 39.06, f(x) = 151.76
# Iter 272: x = -84.82, f(x) = 719.25
# Iter 273: x = 254.83, f(x) = 6494.61
# Iter 274: x = 123.02, f(x) = 1513.95
# Iter 275: x = -322.97, f(x) = 10430.12
# Iter 276: x = 466.01, f(x) = 21715.47
# Iter 277: x = 87.36, f(x) = 762.94
# Iter 278: x = -253.62, f(x) = 6431.98
# Iter 279: x = 734.83, f(x) = 53998.95
# Iter 280: x = 202.07, f(x) = 4083.95
# Iter 281: x = -536.69, f(x) = 28803.80
# Iter 282: x = -415.50, f(x) = 17264.56
# Iter 283: x = 966.32, f(x) = 93376.24
# Iter 284: x = -2634.27, f(x) = 693938.87
# Iter 285: x = 1845.38, f(x) = 340543.18
# Iter 286: x = -3912.09, f(x) = 1530448.10
# Iter 287: x = -2610.38, f(x) = 681407.83
# Iter 288: x = 4725.92, f(x) = 2233435.44
# Iter 289: x = 2772.43, f(x) = 768639.96
# Iter 290: x = -2595.60, f(x) = 673715.75
# Iter 291: x = -1968.69, f(x) = 387574.70
# Iter 292: x = 5293.03, f(x) = 2801619.07
# Iter 293: x = -7236.78, f(x) = 5237097.30
# Iter 294: x = 14360.65, f(x) = 20622832.06
# Iter 295: x = 12496.63, f(x) = 15616580.96
# Iter 296: x = -6593.45, f(x) = 4347359.91
# Iter 297: x = 9813.86, f(x) = 9631175.75
# Iter 298: x = 1451.39, f(x) = 210654.54
# Iter 299: x = -2001.65, f(x) = 400659.79
# Iter 300: x = -322.13, f(x) = 10377.12
# Iter 301: x = 905.16, f(x) = 81931.54
# Iter 302: x = -2126.95, f(x) = 452389.65
# Iter 303: x = -539.27, f(x) = 29081.01
# Iter 304: x = 1355.64, f(x) = 183775.22
# Iter 305: x = 954.51, f(x) = 91109.10
# Iter 306: x = -2291.98, f(x) = 525317.60
# Iter 307: x = 6483.94, f(x) = 4204143.48
# Iter 308: x = 6334.93, f(x) = 4013127.08
# Iter 309: x = -15911.32, f(x) = 25317003.50
# Iter 310: x = 36387.81, f(x) = 132407250.51
# Iter 311: x = -108694.14, f(x) = 1181441682.49
# Iter 312: x = -56752.60, f(x) = 322085790.07
# Iter 313: x = 84881.53, f(x) = 720487425.48
# Iter 314: x = -15944.52, f(x) = 25422766.76
# Iter 315: x = 45530.99, f(x) = 207307095.74
# Iter 316: x = 33975.36, f(x) = 115432508.73
# Iter 317: x = 10247.88, f(x) = 10501902.59
# Iter 318: x = -14475.46, f(x) = 20953888.64
# Iter 319: x = 6823.45, f(x) = 4655940.52
# Iter 320: x = -9020.53, f(x) = 8136997.62
# Iter 321: x = 19691.57, f(x) = 38775798.73
# Iter 322: x = 19219.26, f(x) = 36937985.36
# Iter 323: x = 6670.89, f(x) = 4450072.85
# Iter 324: x = 297.93, f(x) = 8874.98
# Iter 325: x = -307.59, f(x) = 9461.53
# Iter 326: x = -213.13, f(x) = 4541.95
# Iter 327: x = -133.55, f(x) = 1784.00
# Iter 328: x = -121.69, f(x) = 1480.88
# Iter 329: x = -125.59, f(x) = 1577.82
# Iter 330: x = 339.98, f(x) = 11559.01
# Iter 331: x = -986.95, f(x) = 97405.75
# Iter 332: x = -836.61, f(x) = 69990.61
# Iter 333: x = 1546.40, f(x) = 239134.03
# Iter 334: x = -4628.57, f(x) = 2142369.78
# Iter 335: x = 340.29, f(x) = 11580.38
# Iter 336: x = 28.95, f(x) = 83.44
# Iter 337: x = 21.65, f(x) = 47.67
# Iter 338: x = -45.63, f(x) = 208.80
# Iter 339: x = 121.51, f(x) = 1477.41
# Iter 340: x = -15.68, f(x) = 24.44
# Iter 341: x = 50.63, f(x) = 255.59
# Iter 342: x = 9.88, f(x) = 9.67
# Iter 343: x = -25.58, f(x) = 66.01
# Iter 344: x = 69.71, f(x) = 485.74
# Iter 345: x = -202.21, f(x) = 4087.92
# Iter 346: x = 79.64, f(x) = 633.90
# Iter 347: x = -224.02, f(x) = 5018.60
# Iter 348: x = 668.17, f(x) = 44644.12
# Iter 349: x = -1868.35, f(x) = 349071.75
# Iter 350: x = -1871.07, f(x) = 350088.82
# Iter 351: x = 636.18, f(x) = 40471.95
# Iter 352: x = -1804.54, f(x) = 325636.15
# Iter 353: x = 653.48, f(x) = 42702.30
# Iter 354: x = -1508.21, f(x) = 227467.70
# Iter 355: x = 2942.18, f(x) = 865641.63
# Iter 356: x = -8550.17, f(x) = 7310537.47
# Iter 357: x = 4753.24, f(x) = 2259326.33
# Iter 358: x = -4248.51, f(x) = 1804987.56
# Iter 359: x = 10534.68, f(x) = 11097957.62
# Iter 360: x = -26432.62, f(x) = 69868356.96
# Iter 361: x = 69293.57, f(x) = 480159945.50
# Iter 362: x = 60591.97, f(x) = 367138668.46
# Iter 363: x = -18076.69, f(x) = 32676664.42
# Iter 364: x = -484.51, f(x) = 23474.61
# Iter 365: x = 1457.14, f(x) = 212325.65
# Iter 366: x = -4358.85, f(x) = 1899953.20
# Iter 367: x = -4291.81, f(x) = 1841966.50
# Iter 368: x = 6476.90, f(x) = 4195018.64
# Iter 369: x = -12431.80, f(x) = 15454958.28
# Iter 370: x = -9867.98, f(x) = 9737694.53
# Iter 371: x = -8001.99, f(x) = 6403186.82
# Iter 372: x = 15042.96, f(x) = 22629055.82
# Iter 373: x = 7827.76, f(x) = 6127385.70
# Iter 374: x = -2400.66, f(x) = 576317.69
# Iter 375: x = 4941.60, f(x) = 2441936.31
# Iter 376: x = -10285.67, f(x) = 10579505.72
# Iter 377: x = -9522.47, f(x) = 9067736.81
# Iter 378: x = 8271.85, f(x) = 6842355.09
# Iter 379: x = -24062.71, f(x) = 57901390.80
# Iter 380: x = -22241.40, f(x) = 49467966.58
# Iter 381: x = 24562.12, f(x) = 60329770.05
# Iter 382: x = 12105.48, f(x) = 14654258.51
# Iter 383: x = -35462.62, f(x) = 125759749.79
# Iter 384: x = -23866.92, f(x) = 56962972.98
# Iter 385: x = 61654.61, f(x) = 380129132.79
# Iter 386: x = 38302.05, f(x) = 146704666.51
# Iter 387: x = -779.21, f(x) = 60716.90
# Iter 388: x = 2309.08, f(x) = 533186.02
# Iter 389: x = -5363.03, f(x) = 2876209.73
# Iter 390: x = -1117.36, f(x) = 124848.80
# Iter 391: x = -1071.70, f(x) = 114853.83
# Iter 392: x = 2958.66, f(x) = 875365.78
# Iter 393: x = 2949.17, f(x) = 869759.02
# Iter 394: x = -7107.35, f(x) = 5051448.34
# Iter 395: x = -4878.05, f(x) = 2379532.28
# Iter 396: x = 14427.15, f(x) = 20814266.95
# Iter 397: x = -42470.62, f(x) = 180375325.55
# Iter 398: x = -41934.84, f(x) = 175853096.74
# Iter 399: x = 78174.27, f(x) = 611121571.86
# Iter 400: x = -142483.51, f(x) = 2030155151.26
# Iter 401: x = 135919.25, f(x) = 1847404388.49
# Iter 402: x = 83998.75, f(x) = 705578955.18
# Iter 403: x = -251976.58, f(x) = 6349219775.88
# Iter 404: x = -223968.33, f(x) = 5016181248.66
# Iter 405: x = -223451.74, f(x) = 4993068148.52
# Iter 406: x = -16035.91, f(x) = 25715035.93
# Iter 407: x = 48041.00, f(x) = 230793803.81
# Iter 408: x = -59265.18, f(x) = 351236149.40
# Iter 409: x = 84606.57, f(x) = 715827246.26
# Iter 410: x = 26850.45, f(x) = 72094649.37
# Iter 411: x = 113.51, f(x) = 1288.07
# Iter 412: x = -307.71, f(x) = 9467.93
# Iter 413: x = -52.80, f(x) = 277.87
# Iter 414: x = 87.53, f(x) = 766.59
# Iter 415: x = 66.93, f(x) = 448.46
# Iter 416: x = -175.90, f(x) = 3093.26
# Iter 417: x = 125.74, f(x) = 1580.13
# Iter 418: x = -39.40, f(x) = 156.24
# Iter 419: x = 22.95, f(x) = 52.59
# Iter 420: x = -64.70, f(x) = 417.70
# Iter 421: x = 113.42, f(x) = 1285.92
# Iter 422: x = 79.71, f(x) = 636.09
# Iter 423: x = -194.12, f(x) = 3769.29
# Iter 424: x = 361.43, f(x) = 13064.20
# Iter 425: x = -765.48, f(x) = 58595.63
# Iter 426: x = 661.46, f(x) = 43753.25
# Iter 427: x = 653.73, f(x) = 42736.38
# Iter 428: x = -1805.05, f(x) = 325822.90
# Iter 429: x = 3644.53, f(x) = 1328261.57
# Iter 430: x = -2024.87, f(x) = 410008.96
# Iter 431: x = 5961.64, f(x) = 3554120.53
# Iter 432: x = -7678.18, f(x) = 5895450.52
# Iter 433: x = 22940.27, f(x) = 52625614.11
# Iter 434: x = -52636.86, f(x) = 277063932.23
# Iter 435: x = 60426.40, f(x) = 365134934.50
# Iter 436: x = -177558.73, f(x) = 3152710270.80
# Iter 437: x = 34595.39, f(x) = 119684084.33
# Iter 438: x = -74168.88, f(x) = 550102223.29
# Iter 439: x = 204102.25, f(x) = 4165772870.50
# Iter 440: x = -331129.80, f(x) = 10964694606.83
# Iter 441: x = 413875.38, f(x) = 17129283409.45
# Iter 442: x = -1113717.89, f(x) = 124036754281.04
# Iter 443: x = 469368.39, f(x) = 22030668406.23
# Iter 444: x = -600336.93, f(x) = 36040443346.39
# Iter 445: x = -526361.17, f(x) = 27705607792.82
# Iter 446: x = 1459347.88, f(x) = 212969624882.44
# Iter 447: x = -812943.63, f(x) = 66087735181.22
# Iter 448: x = -699592.77, f(x) = 48943003732.42
# Iter 449: x = 1411911.11, f(x) = 199349299023.39
# Iter 450: x = 596786.76, f(x) = 35615444186.94
# Iter 451: x = -1536918.30, f(x) = 236211787117.11
# Iter 452: x = 1341156.47, f(x) = 179870068882.91
# Iter 453: x = -1719398.80, f(x) = 295633221680.70
# Iter 454: x = 5104895.79, f(x) = 2605996104857.11
# Iter 455: x = -915152.35, f(x) = 83750382432.33
# Iter 456: x = 861135.06, f(x) = 74155359303.81
# Iter 457: x = -183603.52, f(x) = 3371025346.18
# Iter 458: x = 440688.80, f(x) = 19420662145.90
# Iter 459: x = -387175.08, f(x) = 14990454180.33
# Iter 460: x = 490524.29, f(x) = 24061407492.52
# Iter 461: x = 486830.92, f(x) = 23700434179.05
# Iter 462: x = -67320.43, f(x) = 453204056.58
# Iter 463: x = 109849.57, f(x) = 1206692711.56
# Iter 464: x = -190155.95, f(x) = 3615928587.79
# Iter 465: x = 250049.29, f(x) = 6252464590.25
# Iter 466: x = 29924.75, f(x) = 89549059.27
# Iter 467: x = -23067.78, f(x) = 53212232.88
# Iter 468: x = -22341.30, f(x) = 49913389.83
# Iter 469: x = 65842.31, f(x) = 433520919.87
# Iter 470: x = -151777.36, f(x) = 2303636708.45
# Iter 471: x = 355412.57, f(x) = 12631809268.53
# Iter 472: x = -1045006.82, f(x) = 109203925791.06
# Iter 473: x = 3111572.76, f(x) = 968188501700.03
# Iter 474: x = 1076689.76, f(x) = 115926084164.75
# Iter 475: x = -3221612.28, f(x) = 1037878568602.53
# Iter 476: x = -2194314.38, f(x) = 481501559551.28
# Iter 477: x = -1934793.59, f(x) = 374342623057.57
# Iter 478: x = 883653.07, f(x) = 78084274243.43
# Iter 479: x = -328601.71, f(x) = 10797908056.09
# Iter 480: x = 608122.95, f(x) = 36981352361.44
# Iter 481: x = -1230905.36, f(x) = 151512799502.81
# Iter 482: x = -878294.27, f(x) = 77140083172.37
# Iter 483: x = 790437.79, f(x) = 62479190366.44
# Iter 484: x = -580847.86, f(x) = 33738423652.02
# Iter 485: x = 1026295.27, f(x) = 105328198465.94
# Iter 486: x = -2966624.78, f(x) = 880086256389.55
# Iter 487: x = 8604758.92, f(x) = 7404187608149.01
# Iter 488: x = -21113323.88, f(x) = 44577244514485.51
# Iter 489: x = 8148759.82, f(x) = 6640228662319.29
# Iter 490: x = 8143429.76, f(x) = 6631544822701.59
# Iter 491: x = -13149678.73, f(x) = 17291405061274.17
# Iter 492: x = 16530944.62, f(x) = 27327213018710.60
# Iter 493: x = -11980405.31, f(x) = 14353011139266.69
# Iter 494: x = 22850469.59, f(x) = 52214396045049.39
# Iter 495: x = 10736402.96, f(x) = 11527034857621.71
# Iter 496: x = 10614179.49, f(x) = 11266080626508.42
# Iter 497: x = -31426942.56, f(x) = 98765271850019.48
# Iter 498: x = 79997765.25, f(x) = 639964244552901.12
# Iter 499: x = -233161664.85, f(x) = 5436436195367946.00
# Iter 500: x = 677619254.42, f(x) = 45916785395510720.00
# Iter 501: x = -1646502766.24, f(x) = 271097135923000064.00
# Iter 502: x = 251933931.20, f(x) = 6347070568924895.00
# Iter 503: x = -572857194.96, f(x) = 32816536581348576.00
# Iter 504: x = 1242564012.84, f(x) = 154396532600816672.00
# Iter 505: x = -367084732.38, f(x) = 13475120074752344.00
# Iter 506: x = 485409939.16, f(x) = 23562280903392672.00
# Iter 507: x = -463939146.75, f(x) = 21523953188416328.00
# Iter 508: x = 850305038.37, f(x) = 72301865827666192.00
# Iter 509: x = -817786561.59, f(x) = 66877486032158392.00
# Iter 510: x = -728879525.78, f(x) = 53126536309543928.00
# Iter 511: x = -717591929.13, f(x) = 51493817675559096.00
# Iter 512: x = 1423881530.00, f(x) = 202743861146585216.00
# Iter 513: x = -4244941335.13, f(x) = 1801952693868984320.00
# Iter 514: x = 11555796987.73, f(x) = 13353644402170404864.00
# Iter 515: x = -34656620204.80, f(x) = 120108132401962713088.00
# Iter 516: x = 42281670537.55, f(x) = 178773966344614084608.00
# Iter 517: x = -80591627510.66, f(x) = 649501042481693327360.00
# Iter 518: x = 193848510780.06, f(x) = 3757724513164841189376.00
# Iter 519: x = -85166589706.01, f(x) = 725334800215167336448.00
# Iter 520: x = 222693809116.84, f(x) = 4959253261896883634176.00
# Iter 521: x = -478229668538.24, f(x) = 22870361587019797233664.00
# Iter 522: x = 1395671181452.89, f(x) = 194789804673809403346944.00
# Iter 523: x = 581206089036.10, f(x) = 33780051793263718301696.00
# Iter 524: x = -1560074221604.73, f(x) = 243383157691559457062912.00
# Iter 525: x = 2559114565953.11, f(x) = 654906736167339184619520.00
# Iter 526: x = -7021795337118.06, f(x) = 4930560975637296910958592.00
# Iter 527: x = 3701131281879.72, f(x) = 1369837276570859578851328.00
# Iter 528: x = -1649146749428.63, f(x) = 271968500115101949362176.00
# Iter 529: x = 3684056504743.04, f(x) = 1357227233013949844684800.00
# Iter 530: x = -11051028550261.59, f(x) = 12212523201869678236401664.00
# Iter 531: x = 18269479502557.70, f(x) = 33377388129437595591507968.00
# Iter 532: x = -12991200521334.21, f(x) = 16877129098551438778302464.00
# Iter 533: x = 20143636616417.17, f(x) = 40576609613426267648950272.00
# Iter 534: x = -40038436470186.45, f(x) = 160307639497715664732291072.00
# Iter 535: x = 29165185993865.59, f(x) = 85060807405677324986744832.00
# Iter 536: x = 16885355246795.90, f(x) = 28511522181049779482525696.00
# Iter 537: x = 16390049945099.20, f(x) = 26863373720284626772033536.00
# Iter 538: x = -13728470409496.79, f(x) = 18847089978442907404730368.00
# Iter 539: x = -12130965598843.47, f(x) = 14716032636032376551505920.00
# Iter 540: x = -12130041779830.23, f(x) = 14713791358042685579460608.00
# Iter 541: x = -9481700323661.19, f(x) = 8990264102771674677510144.00
# Iter 542: x = 15736451626395.04, f(x) = 24763590978987108480319488.00
# Iter 543: x = 11535848737468.62, f(x) = 13307580609375644791341056.00
# Iter 544: x = 10972519948848.37, f(x) = 12039619402787542569844736.00
# Iter 545: x = 6627455061575.00, f(x) = 4392316059319602438471680.00
# Iter 546: x = -18433005019694.84, f(x) = 33977567405609516825313280.00
# Iter 547: x = 49117937176993.12, f(x) = 241257175252304347013316608.00
# Iter 548: x = 38242825667191.19, f(x) = 146251371501117702919946240.00
# Iter 549: x = 22554552058939.12, f(x) = 50870781857939518486740992.00
# Iter 550: x = -67618745220236.81, f(x) = 457229470515929914726678528.00
# Iter 551: x = 173610028112119.00, f(x) = 3014044186109075129435684864.00
# Iter 552: x = 140366276077745.53, f(x) = 1970269145993387806191255552.00
# Iter 553: x = 25835191158508.52, f(x) = 66745710219667663021408256.00
# Iter 554: x = -37520398442874.45, f(x) = 140778029931205583668510720.00
# Iter 555: x = 109497181308364.36, f(x) = 1198963271447681646553202688.00
# Iter 556: x = -25948876138072.70, f(x) = 67334417282903889753931776.00
# Iter 557: x = 5736855819489.87, f(x) = 3291151469361480310194176.00
# Iter 558: x = -15484683009680.12, f(x) = 23977540791027623889207296.00
# Iter 559: x = 46301709459605.47, f(x) = 214384829888171888259104768.00
# Iter 560: x = -136969274894182.09, f(x) = 1876058226503802214854688768.00
# Iter 561: x = -78987567325894.20, f(x) = 623903579206267064215928832.00
# Iter 562: x = 233577384672867.00, f(x) = 5455839463061648577398833152.00
# Iter 563: x = -403183386230547.38, f(x) = 16255684293233075783613808640.00
# Iter 564: x = -395720679115925.00, f(x) = 15659485587996888612783259648.00
# Iter 565: x = -208134442505383.50, f(x) = 4331994615702679652036247552.00
# Iter 566: x = -110136473256857.48, f(x) = 1213004274145848342662348800.00
# Iter 567: x = -6044438650257.56, f(x) = 3653523859672746489282560.00
# Iter 568: x = 7150010937551.64, f(x) = 5112265640710814910382080.00
# Iter 569: x = -20419446670499.99, f(x) = 41695380232939309453279232.00
# Iter 570: x = -18464469459939.23, f(x) = 34093663243702836257619968.00
# Iter 571: x = -263185901858.10, f(x) = 6926681893686021718016.00
# Iter 572: x = 388745371813.12, f(x) = 15112296410612366311424.00
# Iter 573: x = -375954299039.58, f(x) = 14134163496633871892480.00
# Iter 574: x = -375750248767.89, f(x) = 14118824944912862019584.00
# Iter 575: x = -199045961271.05, f(x) = 3961929469831530151936.00
# Iter 576: x = -39490837155.40, f(x) = 155952621923418341376.00
# Iter 577: x = -39366763763.56, f(x) = 154974208921579388928.00
# Iter 578: x = 21703957420.82, f(x) = 47106176772494409728.00
# Iter 579: x = -56940516703.90, f(x) = 324222244250715947008.00
# Iter 580: x = -44317537138.64, f(x) = 196404409803455201280.00
# Iter 581: x = 110981043695.13, f(x) = 1231679205965950615552.00
# Iter 582: x = -99308210783.69, f(x) = 986212072905792684032.00
# Iter 583: x = 84323593554.79, f(x) = 711046842999381164032.00
# Iter 584: x = -251997353036.73, f(x) = 6350266593751586570240.00
# Iter 585: x = 592076664091.24, f(x) = 35055477616140523405312.00
# Iter 586: x = -1213620811408.65, f(x) = 147287547388418334916608.00
# Iter 587: x = 1004451812371.93, f(x) = 100892344337726068228096.00
# Iter 588: x = -1424584144693.45, f(x) = 202943998531198242521088.00
# Iter 589: x = 3369947151066.64, f(x) = 1135654380098217320644608.00
# Iter 590: x = -7194654707184.25, f(x) = 5176305635560855728816128.00
# Iter 591: x = -2915448165092.74, f(x) = 849983800334262709780480.00
# Iter 592: x = -1161963181530.22, f(x) = 135015843523183138308096.00
# Iter 593: x = -775719592216.13, f(x) = 60174088574795469815808.00
# Iter 594: x = -248240327216.20, f(x) = 6162326005640444510208.00
# Iter 595: x = 627798047891.68, f(x) = 39413038893661006331904.00
# Iter 596: x = 622984386784.08, f(x) = 38810954617673140404224.00
# Iter 597: x = 602287619711.71, f(x) = 36275037685799429603328.00
# Iter 598: x = -1797590228111.53, f(x) = 323133062820205158203392.00
# Iter 599: x = 4198093078205.64, f(x) = 1762398549327810083684352.00
# Iter 600: x = 761514056202.59, f(x) = 57990365779411752452096.00
# Iter 601: x = -1955196025140.32, f(x) = 382279149672451817865216.00
# Iter 602: x = 2434233607211.96, f(x) = 592549325448012946735104.00
# Iter 603: x = -5313673896711.79, f(x) = 2823513028059631133392896.00
# Iter 604: x = 10316402755617.66, f(x) = 10642816581611568505028608.00
# Iter 605: x = -29973741876811.10, f(x) = 89842520209769951330828288.00
# Iter 606: x = 17509535289480.81, f(x) = 30658382605357395946242048.00
# Iter 607: x = 2255827115855.36, f(x) = 508875597662830974730240.00
# Iter 608: x = 1487466963566.80, f(x) = 221255796770262455681024.00
# Iter 609: x = 674172453536.95, f(x) = 45450849710803343376384.00
# Iter 610: x = 414803451865.48, f(x) = 17206190367951829336064.00
# Iter 611: x = -296995422403.88, f(x) = 8820628092885868216320.00
# Iter 612: x = -287721201340.06, f(x) = 8278348970056825700352.00
# Iter 613: x = -121510620979.90, f(x) = 1476483101092078682112.00
# Iter 614: x = -16483208135.13, f(x) = 27169615042610503680.00
# Iter 615: x = -12208453351.18, f(x) = 14904633322789386240.00
# Iter 616: x = -632856854.85, f(x) = 40050779873676400.00
# Iter 617: x = -620576233.67, f(x) = 38511486179456856.00
# Iter 618: x = 1598346306.38, f(x) = 255471091512061600.00
# Iter 619: x = 1465391160.83, f(x) = 214737125423911552.00
# Iter 620: x = -4043624762.51, f(x) = 1635090121998670592.00
# Iter 621: x = 11214582573.83, f(x) = 12576686230535319552.00
# Iter 622: x = -31173278863.89, f(x) = 97177331512567218176.00
# Iter 623: x = 91121453954.72, f(x) = 830311937082296631296.00
# Iter 624: x = -33921313735.33, f(x) = 115065552553073344512.00
# Iter 625: x = 63260799704.56, f(x) = 400192877926017662976.00
# Iter 626: x = -78647309114.10, f(x) = 618539923088828923904.00
# Iter 627: x = 35864302917.20, f(x) = 128624822373649416192.00
# Iter 628: x = -94078399242.02, f(x) = 885074520394073243648.00
# Iter 629: x = -10024550161.13, f(x) = 10049160593305749504.00
# Iter 630: x = 19439510269.43, f(x) = 37789455951534120960.00
# Iter 631: x = -39592294760.55, f(x) = 156754980440611586048.00
# Iter 632: x = 60117065085.80, f(x) = 361406151452986638336.00
# Iter 633: x = -86168926008.34, f(x) = 742508380943144452096.00
# Iter 634: x = 38348553701.07, f(x) = 147061157096365228032.00
# Iter 635: x = -111121575468.55, f(x) = 1234800453461202960384.00
# Iter 636: x = 263023786789.80, f(x) = 6918151241724556476416.00
# Iter 637: x = -109065719319.34, f(x) = 1189533113064475328512.00
# Iter 638: x = 255508737083.66, f(x) = 6528471472608740638720.00
# Iter 639: x = -549661862268.84, f(x) = 30212816283284839333888.00
# Iter 640: x = -385791966819.92, f(x) = 14883544166278228869120.00
# Iter 641: x = 579434767334.90, f(x) = 33574464959644618981376.00
# Iter 642: x = 411833200888.44, f(x) = 16960658535401771761664.00
# Iter 643: x = -1219809305627.22, f(x) = 148793474209477201756160.00
# Iter 644: x = 2438632815047.23, f(x) = 594693000662518956294144.00
# Iter 645: x = -5916770426926.84, f(x) = 3500817228495600933142528.00
# Iter 646: x = 8702699946207.52, f(x) = 7573698635372030836342784.00
# Iter 647: x = -18489229647256.42, f(x) = 34185161294898585449529344.00
# Iter 648: x = -18469693609662.25, f(x) = 34112958203479855865004032.00
# Iter 649: x = 51509293103583.18, f(x) = 265320727603084179521142784.00
# Iter 650: x = -143968154214960.62, f(x) = 2072682942806268560392847360.00
# Iter 651: x = 181424671400407.12, f(x) = 3291491139274570719689703424.00
# Iter 652: x = -101655329117113.75, f(x) = 1033380593790871584798408704.00
# Iter 653: x = 275287125487964.25, f(x) = 7578300145942618110762680320.00
# Iter 654: x = 251010909437540.97, f(x) = 6300647665666139490848079872.00
# Iter 655: x = -1278900615933.75, f(x) = 163558678543572511227904.00
# Iter 656: x = 3696353445988.99, f(x) = 1366302879767470536654848.00
# Iter 657: x = -10066419875831.83, f(x) = 10133280911654216282406912.00
# Iter 658: x = -840731542463.57, f(x) = 70682952649317747261440.00
# Iter 659: x = 1317343520884.88, f(x) = 173539395201736862859264.00
# Iter 660: x = -190133691350.65, f(x) = 3615082058662355140608.00
# Iter 661: x = 193345371331.52, f(x) = 3738243261532180840448.00
# Iter 662: x = 103863662117.52, f(x) = 1078766030846302224384.00
# Iter 663: x = -292615598731.94, f(x) = 8562388862125041778688.00
# Iter 664: x = 26357140534.52, f(x) = 69469885715655090176.00
# Iter 665: x = -73456535761.89, f(x) = 539586264613830000640.00
# Iter 666: x = 9370984555.62, f(x) = 8781535154162958336.00
# Iter 667: x = -28112794829.82, f(x) = 79032923314348163072.00
# Iter 668: x = 78223449388.26, f(x) = 611890803419732901888.00
# Iter 669: x = 74609519136.19, f(x) = 556658034573369409536.00
# Iter 670: x = 47828906618.46, f(x) = 228760430831732654080.00
# Iter 671: x = -4381271582.98, f(x) = 1919554068386834944.00
# Iter 672: x = 7480760551.60, f(x) = 5596177843044617216.00
# Iter 673: x = -14457764814.76, f(x) = 20902696343894192128.00
# Iter 674: x = 12265608877.95, f(x) = 15044516114677344256.00
# Iter 675: x = -4900269846.16, f(x) = 2401264456519753216.00
# Iter 676: x = 4577498815.30, f(x) = 2095349540402831872.00
# Iter 677: x = -1497576480.44, f(x) = 224273531478088160.00
# Iter 678: x = 3767863781.13, f(x) = 1419679747315309568.00
# Iter 679: x = -6768737634.81, f(x) = 4581580916885495296.00
# Iter 680: x = 8905251566.25, f(x) = 7930350545823038464.00
# Iter 681: x = -25942508418.07, f(x) = 67301374302175952896.00
# Iter 682: x = -24144971515.47, f(x) = 58297964948292763648.00
# Iter 683: x = 38005671124.81, f(x) = 144443103764741947392.00
# Iter 684: x = 9888557944.77, f(x) = 9778357822711939072.00
# Iter 685: x = 7242052382.36, f(x) = 5244732270886916096.00
# Iter 686: x = -17978354851.04, f(x) = 32322124314989240320.00
# Iter 687: x = 47571162115.91, f(x) = 226301546505844686848.00
# Iter 688: x = -13622045579.67, f(x) = 18556012577450635264.00
# Iter 689: x = 5388621249.26, f(x) = 2903723896798160896.00
# Iter 690: x = -616064571.17, f(x) = 37953555585410280.00
# Iter 691: x = 596643566.69, f(x) = 35598354567377884.00
# Iter 692: x = -1226696485.98, f(x) = 150478426871301088.00
# Iter 693: x = 3540022421.53, f(x) = 1253175874492296704.00
# Iter 694: x = -6484823389.77, f(x) = 4205293439653912576.00
# Iter 695: x = -1259394012.17, f(x) = 158607327789862944.00
# Iter 696: x = -431131530.39, f(x) = 18587439649597520.00
# Iter 697: x = -367034675.70, f(x) = 13471445316553818.00
# Iter 698: x = 166047679.49, f(x) = 2757183186303229.00
# Iter 699: x = 144620814.25, f(x) = 2091517991309303.25
# Iter 700: x = 27981163.07, f(x) = 78294548654638.28
# Iter 701: x = 10071783.42, f(x) = 10144082134967.94
# Iter 702: x = -23747151.55, f(x) = 56392720662388.91
# Iter 703: x = 40386172.92, f(x) = 163104296339878.88
# Iter 704: x = 31780768.35, f(x) = 101001723689827.41
# Iter 705: x = -57423820.09, f(x) = 329749511420007.00
# Iter 706: x = -42141630.44, f(x) = 177591701596963.84
# Iter 707: x = 105909415.02, f(x) = 1121680418909685.00
# Iter 708: x = -2816153.53, f(x) = 793072068453.29
# Iter 709: x = 2424960.07, f(x) = 588043135195.39
# Iter 710: x = -7089429.40, f(x) = 5026000915902.91
# Iter 711: x = -6062540.16, f(x) = 3675439320181.15
# Iter 712: x = -4728594.59, f(x) = 2235960683369.23
# Iter 713: x = 13801294.80, f(x) = 19047573827203.67
# Iter 714: x = -18943982.32, f(x) = 35887446605048.93
# Iter 715: x = 13460523.02, f(x) = 18118568007196.64
# Iter 716: x = -9889459.07, f(x) = 9780140060017.34
# Iter 717: x = 10195708.41, f(x) = 10395246989696.81
# Iter 718: x = 8790058.25, f(x) = 7726512410811.89
# Iter 719: x = -23966705.18, f(x) = 57440295731160.87
# Iter 720: x = 10241273.29, f(x) = 10488367852724.33
# Iter 721: x = -6174311.87, f(x) = 3812212712339.19
# Iter 722: x = -3294974.37, f(x) = 1085685608919.97
# Iter 723: x = 9884024.24, f(x) = 9769393524191.15
# Iter 724: x = 4620827.98, f(x) = 2135205120370.89
# Iter 725: x = -12501814.71, f(x) = 15629537099057.69
# Iter 726: x = -11922881.17, f(x) = 14215509536627.52
# Iter 727: x = -10218417.95, f(x) = 10441606535526.89
# Iter 728: x = -8950883.19, f(x) = 8011830992884.89
# Iter 729: x = 1299340.45, f(x) = 168828560280.54
# Iter 730: x = -3262476.93, f(x) = 1064375574679.77
# Iter 731: x = 5065770.38, f(x) = 2566202959019.80
# Iter 732: x = -13971761.29, f(x) = 19521011356333.42
# Iter 733: x = -13342286.85, f(x) = 17801661827055.02
# Iter 734: x = 956445.78, f(x) = 91478853106.96
# Iter 735: x = -2540918.21, f(x) = 645626534811.48
# Iter 736: x = -462519.63, f(x) = 21392441188.57
# Iter 737: x = 1371957.89, f(x) = 188226844780.77
# Iter 738: x = -4096213.79, f(x) = 1677896742601.75
# Iter 739: x = 12285806.89, f(x) = 15094105092467.88
# Iter 740: x = -35154985.84, f(x) = 123587302919346.92
# Iter 741: x = 9411782.33, f(x) = 8858164655613.47
# Iter 742: x = -24690707.60, f(x) = 60963104198120.70
# Iter 743: x = -8777698.44, f(x) = 7704798997382.22
# Iter 744: x = 5197224.58, f(x) = 2701114328885.54
# Iter 745: x = -15474595.94, f(x) = 23946311942395.35
# Iter 746: x = 43197287.22, f(x) = 186600562330445.06
# Iter 747: x = -129587915.62, f(x) = 1679302787501286.50
# Iter 748: x = 28229098.15, f(x) = 79688198255207.80
# Iter 749: x = -79992233.34, f(x) = 639875739473951.00
# Iter 750: x = 235199013.68, f(x) = 5531857603642796.00
# Iter 751: x = -370800114.04, f(x) = 13749272457000710.00
# Iter 752: x = -319645960.94, f(x) = 10217354034516024.00
# Iter 753: x = 663450886.27, f(x) = 44016707849427120.00
# Iter 754: x = -1826269672.74, f(x) = 333526091756806848.00
# Iter 755: x = 3674187176.19, f(x) = 1349965140571428608.00
# Iter 756: x = -9209237017.61, f(x) = 8481004644656307200.00
# Iter 757: x = -2322461036.22, f(x) = 539382526474734208.00
# Iter 758: x = 6831680412.96, f(x) = 4667185726486342656.00
# Iter 759: x = 6830732011.49, f(x) = 4665889981276438528.00
# Iter 760: x = 2335898834.14, f(x) = 545642336332550592.00
# Iter 761: x = -6035341535.61, f(x) = 3642534745143546368.00
# Iter 762: x = -4366075792.32, f(x) = 1906261782426433536.00
# Iter 763: x = 6362319120.28, f(x) = 4047910458833073152.00
# Iter 764: x = 6152731038.41, f(x) = 3785609923095715840.00
# Iter 765: x = -2855848461.19, f(x) = 815587043327911552.00
# Iter 766: x = 239725743.01, f(x) = 5746843186124836.00
# Iter 767: x = -717469861.05, f(x) = 51476300151175096.00
# Iter 768: x = -585428048.58, f(x) = 34272600006989376.00
# Iter 769: x = 1749563890.87, f(x) = 306097380824560640.00
# Iter 770: x = -4840184864.17, f(x) = 2342738951937376256.00
# Iter 771: x = 1234000105.39, f(x) = 152275626010723232.00
# Iter 772: x = -3509164993.25, f(x) = 1231423894982836224.00
# Iter 773: x = 8428907645.43, f(x) = 7104648409512251392.00
# Iter 774: x = 7939455820.75, f(x) = 6303495872968070144.00
# Iter 775: x = -14436133220.33, f(x) = 20840194235510231040.00
# Iter 776: x = -14300992241.03, f(x) = 20451837907789393920.00
# Iter 777: x = 11969187939.76, f(x) = 14326145993726255104.00
# Iter 778: x = -14141119686.59, f(x) = 19997126599034130432.00
# Iter 779: x = 6690256042.36, f(x) = 4475952591228889600.00
# Iter 780: x = 5265009249.11, f(x) = 2772032239326476800.00
# Iter 781: x = -7784011063.09, f(x) = 6059082823033356288.00
# Iter 782: x = 3063536043.98, f(x) = 938525309275867776.00
# Iter 783: x = 3056420676.35, f(x) = 934170735084649984.00
# Iter 784: x = -1941880456.50, f(x) = 377089970733640768.00
# Iter 785: x = 5824740716.85, f(x) = 3392760441856017920.00
# Iter 786: x = 363212921.70, f(x) = 13192362648745044.00
# Iter 787: x = -856822359.38, f(x) = 73414455553209120.00
# Iter 788: x = -632782578.53, f(x) = 40041379168765952.00
# Iter 789: x = -58443632.72, f(x) = 341565820514955.25
# Iter 790: x = -4242752.00, f(x) = 1800094451117.96
# Iter 791: x = 10188963.10, f(x) = 10381496912954.57
# Iter 792: x = 8339030.08, f(x) = 6953942272561.35
# Iter 793: x = -19440033.31, f(x) = 37791489513302.14
# Iter 794: x = 17691203.16, f(x) = 31297866921508.03
# Iter 795: x = -16510004.61, f(x) = 27258025215553.22
# Iter 796: x = 13661704.39, f(x) = 18664216697337.49
# Iter 797: x = 12833994.65, f(x) = 16471141870115.44
# Iter 798: x = -21469551.74, f(x) = 46094165197071.41
# Iter 799: x = -21391095.42, f(x) = 45757896338796.52
# Iter 800: x = -20037606.52, f(x) = 40150567514195.67
# Iter 801: x = 54150608.36, f(x) = 293228838596990.88
# Iter 802: x = -157759014.92, f(x) = 2488790678932449.50
# Iter 803: x = 63341132.41, f(x) = 401209905474477.62
# Iter 804: x = 13058366.52, f(x) = 17052093628828.13
# Iter 805: x = -6564437.00, f(x) = 4309183306687.86
# Iter 806: x = 3131818.27, f(x) = 980828568755.47
# Iter 807: x = 2544866.80, f(x) = 647634700476.48
# Iter 808: x = 686238.14, f(x) = 47092278635.45
# Iter 809: x = -2015015.87, f(x) = 406028894900.42
# Iter 810: x = -1957726.95, f(x) = 383269479873.80
# Iter 811: x = 5872400.37, f(x) = 3448508605923.14
# Iter 812: x = -17447548.89, f(x) = 30441696213787.60
# Iter 813: x = 29214603.91, f(x) = 85349308175164.17
# Iter 814: x = 21261981.27, f(x) = 45207184744609.95
# Iter 815: x = 11911689.80, f(x) = 14188835390566.22
# Iter 816: x = -31966848.27, f(x) = 102187938863610.12
# Iter 817: x = 80158840.46, f(x) = 642543970385554.25
# Iter 818: x = -219964767.65, f(x) = 4838449900752677.00
# Iter 819: x = 649140084.70, f(x) = 42138284956743320.00
# Iter 820: x = -1505327234.01, f(x) = 226601008143899520.00
# Iter 821: x = -1197895356.41, f(x) = 143495328490034848.00
# Iter 822: x = 2412912621.01, f(x) = 582214731664544768.00
# Iter 823: x = 799473614.24, f(x) = 63915805986652992.00
# Iter 824: x = -867700060.55, f(x) = 75290339507156768.00
# Iter 825: x = 618666101.16, f(x) = 38274774472461720.00
# Iter 826: x = 590196584.42, f(x) = 34833200825722152.00
# Iter 827: x = -1243764712.02, f(x) = 154695065887186016.00
# Iter 828: x = 1803918990.91, f(x) = 325412372575719808.00
# Iter 829: x = 1033285157.51, f(x) = 106767821673655440.00
# Iter 830: x = 265370472.73, f(x) = 7042148779611935.00
# Iter 831: x = -659565619.50, f(x) = 43502680642865192.00
# Iter 832: x = 1115793520.31, f(x) = 124499517996357440.00
# Iter 833: x = 333762752.83, f(x) = 11139757517708106.00
# Iter 834: x = -268588866.36, f(x) = 7213997913297637.00
# Iter 835: x = -267082928.86, f(x) = 7133329088693911.00
# Iter 836: x = -218218589.61, f(x) = 4761935285354087.00
# Iter 837: x = 654602925.05, f(x) = 42850498948950888.00
# Iter 838: x = -360489171.55, f(x) = 12995244280812888.00
# Iter 839: x = 696506221.21, f(x) = 48512091618115264.00
# Iter 840: x = 580357740.90, f(x) = 33681510742520752.00
# Iter 841: x = -1140100136.65, f(x) = 129982832159324480.00
# Iter 842: x = 2792082679.42, f(x) = 779572568870003200.00
# Iter 843: x = -1050857150.56, f(x) = 110430075088200816.00
# Iter 844: x = 771060401.37, f(x) = 59453414256362000.00
# Iter 845: x = -2215822774.59, f(x) = 490987056838228096.00
# Iter 846: x = 6549941720.44, f(x) = 4290173654119385600.00
# Iter 847: x = -18212288963.75, f(x) = 33168746929920757760.00
# Iter 848: x = 54084469735.21, f(x) = 292512986653834149888.00
# Iter 849: x = 24778177655.77, f(x) = 61395808794106789888.00
# Iter 850: x = 12643578896.44, f(x) = 15986008731039741952.00
# Iter 851: x = -12733520241.05, f(x) = 16214253772912955392.00
# Iter 852: x = 19866698977.75, f(x) = 39468572827243077632.00
# Iter 853: x = -51303734434.26, f(x) = 263207316690094587904.00
# Iter 854: x = -46153619559.91, f(x) = 213015659848114470912.00
# Iter 855: x = -23347219650.71, f(x) = 54509266541829750784.00
# Iter 856: x = 50337029527.08, f(x) = 253381654161003708416.00
# Iter 857: x = -73919629072.28, f(x) = 546411156218401783808.00
# Iter 858: x = 221719975213.61, f(x) = 4915974740872484880384.00
# Iter 859: x = 72281371437.73, f(x) = 522459665691873443840.00
# Iter 860: x = 70685177734.59, f(x) = 499639435137045495808.00
# Iter 861: x = 6500778256.81, f(x) = 4226011794420926976.00
# Iter 862: x = 1003485312.78, f(x) = 100698277295523072.00
# Iter 863: x = 370534211.79, f(x) = 13729560210342194.00
# Iter 864: x = -63863938.64, f(x) = 407860265807962.75
# Iter 865: x = 137721006.63, f(x) = 1896707566851571.25
# Iter 866: x = 79780846.74, f(x) = 636498350696264.88
# Iter 867: x = -227322066.64, f(x) = 5167532198066112.00
# Iter 868: x = 474234518.90, f(x) = 22489837892023968.00
# Iter 869: x = -587337744.51, f(x) = 34496562612397244.00
# Iter 870: x = -587332302.71, f(x) = 34495923381047344.00
# Iter 871: x = 299544892.38, f(x) = 8972714255019098.00
# Iter 872: x = 287175592.06, f(x) = 8246982067256995.00
# Iter 873: x = -465056723.71, f(x) = 21627775627196652.00
# Iter 874: x = 1327451183.48, f(x) = 176212664452381504.00
# Iter 875: x = 521904452.64, f(x) = 27238425768724736.00
# Iter 876: x = -1547616150.51, f(x) = 239511574933414368.00
# Iter 877: x = 2311003467.73, f(x) = 534073702785570240.00
# Iter 878: x = 221315483.11, f(x) = 4898054306296791.00
# Iter 879: x = 198539806.35, f(x) = 3941805470635753.50
# Iter 880: x = 133491044.74, f(x) = 1781985902461543.75
# Iter 881: x = -391893172.28, f(x) = 15358025847732032.00
# Iter 882: x = 958709443.17, f(x) = 91912379642938528.00
# Iter 883: x = -1329780897.25, f(x) = 176831723468518528.00
# Iter 884: x = -1688263.78, f(x) = 285023459496.62
# Iter 885: x = 3252038.14, f(x) = 1057575204592.63
# Iter 886: x = -8045697.26, f(x) = 6473324440156.01
# Iter 887: x = 1150346.11, f(x) = 132329617733.48
# Iter 888: x = 1142284.48, f(x) = 130481383493.91
# Iter 889: x = 1120952.74, f(x) = 125653505169.22
# Iter 890: x = 1117976.35, f(x) = 124987112524.28
# Iter 891: x = 990769.30, f(x) = 98162380782.55
# Iter 892: x = -2939256.54, f(x) = 863922902330.43
# Iter 893: x = 8305087.34, f(x) = 6897447571985.93
# Iter 894: x = -1107717.13, f(x) = 122703725009.03
# Iter 895: x = -868257.98, f(x) = 75387192017.59
# Iter 896: x = -842067.44, f(x) = 70907757117.18
# Iter 897: x = -766133.53, f(x) = 58696058812.64
# Iter 898: x = 1458829.17, f(x) = 212818255318.91
# Iter 899: x = -2844534.65, f(x) = 809137736643.05
# Iter 900: x = 5647324.10, f(x) = 3189226953723.21
# Iter 901: x = -14612080.69, f(x) = 21351290201080.82
# Iter 902: x = 11001158.61, f(x) = 12102549065678.49
# Iter 903: x = 3939883.20, f(x) = 1552267959969.45
# Iter 904: x = -5264581.28, f(x) = 2771581605191.41
# Iter 905: x = -5086451.66, f(x) = 2587199045631.42
# Iter 906: x = -2945712.05, f(x) = 867721950683.26
# Iter 907: x = -2890827.88, f(x) = 835688583299.48
# Iter 908: x = 793530.21, f(x) = 62969019337.04
# Iter 909: x = 792271.15, f(x) = 62769357460.37
# Iter 910: x = -2366834.46, f(x) = 560190535298.64
# Iter 911: x = -2083908.19, f(x) = 434267336100.33
# Iter 912: x = -1635780.52, f(x) = 267577790881.59
# Iter 913: x = -1635763.64, f(x) = 267572269011.46
# Iter 914: x = -1635750.88, f(x) = 267568094587.00
# Iter 915: x = 1824439.37, f(x) = 332857902422.88
# Iter 916: x = -815597.87, f(x) = 66519988938.03
# Iter 917: x = 215879.71, f(x) = 4660405023.24
# Iter 918: x = -647528.02, f(x) = 41929254257.84
# Iter 919: x = 1442147.80, f(x) = 207979026894.88
# Iter 920: x = -3977887.20, f(x) = 1582358658397.82
# Iter 921: x = -3707775.90, f(x) = 1374760211492.46
# Iter 922: x = -2151564.58, f(x) = 462923015149.51
# Iter 923: x = 6432624.42, f(x) = 4137865687543.78
# Iter 924: x = -6211878.58, f(x) = 3858743543719.65
# Iter 925: x = 1917503.65, f(x) = 367682026539.35
# Iter 926: x = -4726349.01, f(x) = 2233837495998.82
# Iter 927: x = 14158925.52, f(x) = 20047517191403.53
# Iter 928: x = 7996240.53, f(x) = 6393986269093.91
# Iter 929: x = -7073045.75, f(x) = 5002797612144.89
# Iter 930: x = 12736403.60, f(x) = 16221597675250.23
# Iter 931: x = 12414076.29, f(x) = 15410929007563.95
# Iter 932: x = 11252881.57, f(x) = 12662734359718.54
# Iter 933: x = -30636778.86, f(x) = 93861221905725.59
# Iter 934: x = -28461803.30, f(x) = 81007424685386.53
# Iter 935: x = 19949789.89, f(x) = 39799411657500.31
# Iter 936: x = -28554859.30, f(x) = 81537998985980.25
# Iter 937: x = 21455481.79, f(x) = 46033769899846.68
# Iter 938: x = -57815078.07, f(x) = 334258325281757.88
# Iter 939: x = 101053846.98, f(x) = 1021187998934083.62
# Iter 940: x = -294839190.41, f(x) = 8693014820214148.00
# Iter 941: x = -161692416.17, f(x) = 2614443744724231.50
# Iter 942: x = 401138176.32, f(x) = 16091183650026708.00
# Iter 943: x = -1197697849.22, f(x) = 143448013802182384.00
# Iter 944: x = -533463953.53, f(x) = 28458378971643872.00
# Iter 945: x = 1068750802.78, f(x) = 114222827844606384.00
# Iter 946: x = 417427434.22, f(x) = 17424566283615368.00
# Iter 947: x = -510313330.76, f(x) = 26041969555141776.00
# Iter 948: x = 739172305.50, f(x) = 54637569721937736.00
# Iter 949: x = -1941588669.41, f(x) = 376976656117238528.00
# Iter 950: x = -873828456.73, f(x) = 76357617178493744.00
# Iter 951: x = 1173414829.29, f(x) = 137690236160361760.00
# Iter 952: x = 903240609.95, f(x) = 81584359946155648.00
# Iter 953: x = -2061662602.71, f(x) = 425045268741926528.00
# Iter 954: x = 5754656774.41, f(x) = 3311607459123978752.00
# Iter 955: x = -767013813.94, f(x) = 58831019077589472.00
# Iter 956: x = -504778366.69, f(x) = 25480119947401344.00
# Iter 957: x = -465801002.14, f(x) = 21697057359628900.00
# Iter 958: x = 450532880.78, f(x) = 20297987666543612.00
# Iter 959: x = -1347075998.59, f(x) = 181461374598429280.00
# Iter 960: x = -1220199763.72, f(x) = 148888746337794880.00
# Iter 961: x = -1078874165.69, f(x) = 116396946538735296.00
# Iter 962: x = 3205956365.36, f(x) = 1027815621658447488.00
# Iter 963: x = -9617375063.77, f(x) = 9249390311716321280.00
# Iter 964: x = -3378743077.34, f(x) = 1141590478268054016.00
# Iter 965: x = -3044581604.28, f(x) = 926947714514166016.00
# Iter 966: x = 7069557453.06, f(x) = 4997864258210429952.00
# Iter 967: x = -20776242386.08, f(x) = 43165224768525492224.00
# Iter 968: x = -19892044199.34, f(x) = 39569342242846474240.00
# Iter 969: x = 12616385951.34, f(x) = 15917319447315363840.00
# Iter 970: x = -28915758066.56, f(x) = 83612106456380391424.00
# Iter 971: x = 69800624693.88, f(x) = 487212720765601644544.00
# Iter 972: x = 65496089590.53, f(x) = 428973775165096001536.00
# Iter 973: x = -192669197150.57, f(x) = 3712141953064516976640.00
# Iter 974: x = 102241614943.94, f(x) = 1045334782634558226432.00
# Iter 975: x = -87955590795.18, f(x) = 773618595212996247552.00
# Iter 976: x = -62188979234.83, f(x) = 386746913826994913280.00
# Iter 977: x = 6164548621.29, f(x) = 3800165970426199552.00
# Iter 978: x = -18275272708.58, f(x) = 33398559257313705984.00
# Iter 979: x = 26726766335.73, f(x) = 71432003876450369536.00
# Iter 980: x = -75071292680.68, f(x) = 563569898474811883520.00
# Iter 981: x = -17451819623.63, f(x) = 30456600817569177600.00
# Iter 982: x = 49944012954.38, f(x) = 249440442998774890496.00
# Iter 983: x = -104959792967.59, f(x) = 1101655813979979251712.00
# Iter 984: x = 130038477646.07, f(x) = 1691000566850654306304.00
# Iter 985: x = 55378457147.36, f(x) = 306677351602159091712.00
# Iter 986: x = -161441812163.59, f(x) = 2606345871466272653312.00
# Iter 987: x = 483211437512.63, f(x) = 23349329334302658265088.00
# Iter 988: x = -887914864461.96, f(x) = 78839280653250657779712.00
# Iter 989: x = 972791005877.47, f(x) = 94632234111610445103104.00
# Iter 990: x = -2590716701006.39, f(x) = 671181302487344952115200.00
# Iter 991: x = -2589825718337.12, f(x) = 670719725136037069979648.00
# Iter 992: x = -2480596844812.32, f(x) = 615336070649282622914560.00
# Iter 993: x = 1429181334871.88, f(x) = 204255928794615864360960.00
# Iter 994: x = 1425742368786.99, f(x) = 203274130215434641735680.00
# Iter 995: x = -3676456578912.10, f(x) = 1351633297662608781869056.00
# Iter 996: x = -2986468821732.32, f(x) = 891899602317921702903808.00
# Iter 997: x = -2982321056256.67, f(x) = 889423888259191068950528.00
# Iter 998: x = 3949349220245.01, f(x) = 1559735926344986830831616.00
# Iter 999: x = -292313468829.26, f(x) = 8544716405899462180864.00
# Iter 1000: x = 501116259912.82, f(x) = 25111750594901305196544.00
# 501116259912.82007

# %% [markdown]
# Let's demonstrate that we could end up in a bad local minimum:

# %%
grad_descent(f, dfdx, -10, 0.1)
# Out:
# Iter 0: x = -9.86, f(x) = 10.72
# Iter 1: x = -9.65, f(x) = 10.16
# Iter 2: x = -9.33, f(x) = 8.98
# Iter 3: x = -8.93, f(x) = 7.38
# Iter 4: x = -8.57, f(x) = 6.36
# Iter 5: x = -8.36, f(x) = 6.03
# Iter 6: x = -8.25, f(x) = 5.92
# Iter 7: x = -8.18, f(x) = 5.88
# Iter 8: x = -8.14, f(x) = 5.87
# Iter 9: x = -8.11, f(x) = 5.86
# Iter 10: x = -8.09, f(x) = 5.86
# Iter 11: x = -8.07, f(x) = 5.86
# Iter 12: x = -8.06, f(x) = 5.86
# Iter 13: x = -8.06, f(x) = 5.86
# Iter 14: x = -8.05, f(x) = 5.85
# Iter 15: x = -8.05, f(x) = 5.85
# Iter 16: x = -8.04, f(x) = 5.85
# Iter 17: x = -8.04, f(x) = 5.85
# Iter 18: x = -8.04, f(x) = 5.85
# Iter 19: x = -8.04, f(x) = 5.85
# Iter 20: x = -8.04, f(x) = 5.85
# -8.036475915977233
